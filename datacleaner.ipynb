# %%
import pandas as pd

# %%
print("Hello world")
# Out:
# Hello world

# %%
book_data = pd.read_csv('Data/book.csv')
book_data
# Out:
#       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye   "20/02/2023"
# 1    2.0          Lord of the rings the two towers  "24/03/2023"
# 2    3.0  Lord of the rings the return of the kind  "29/03/2023"
# 3    4.0                                The hobbit  "02/04/2023"
# 4    5.0                                     Dune   "02/04/2023"
# ..   ...                                       ...           ...
# 109  NaN                                       NaN           NaN
# 110  NaN                                       NaN           NaN
# 111  NaN                                       NaN           NaN
# 112  NaN                                       NaN           NaN
# 113  NaN                                       NaN           NaN
#
#     Book Returned Days allowed to borrow  Customer ID
# 0      25/02/2023                2 weeks          1.0
# 1      21/03/2023                2 weeks          2.0
# ...

# %%
book_data_clean = book_data.copy()

# %%
book_data_clean['Book checkout'] = book_data_clean['Book checkout'].str.replace('"','')

# %%
book_data_clean.head()
# Out:
#     Id                                     Books Book checkout Book Returned  \
# 0  1.0                       Catcher in the Rye     20/02/2023    25/02/2023
# 1  2.0          Lord of the rings the two towers    24/03/2023    21/03/2023
# 2  3.0  Lord of the rings the return of the kind    29/03/2023    25/03/2023
# 3  4.0                                The hobbit    02/04/2023    25/03/2023
# 4  5.0                                     Dune     02/04/2023    25/03/2023
#
#   Days allowed to borrow  Customer ID
# 0                2 weeks          1.0
# 1                2 weeks          2.0
# 2                2 weeks          3.0
# 3                2 weeks          4.0
# 4                2 weeks          5.0

# %%
book_data_clean['Book checkout'] = pd.to_datetime(book_data_clean['Book checkout'], errors='coerce', format='%d/%m/%Y')

# %%
print(book_data_clean)
# Out:
#       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye     2023-02-20
# 1    2.0          Lord of the rings the two towers    2023-03-24
# 2    3.0  Lord of the rings the return of the kind    2023-03-29
# 3    4.0                                The hobbit    2023-04-02
# 4    5.0                                     Dune     2023-04-02
# ..   ...                                       ...           ...
# 109  NaN                                       NaN           NaT
# 110  NaN                                       NaN           NaT
# 111  NaN                                       NaN           NaT
# 112  NaN                                       NaN           NaT
# 113  NaN                                       NaN           NaT
#
#     Book Returned Days allowed to borrow  Customer ID
# 0      25/02/2023                2 weeks          1.0
# 1      21/03/2023                2 weeks          2.0
# ...

# %%
book_data_clean.dropna(inplace=True)

# %%
book_data_clean
# Out:
#       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye     2023-02-20
# 1    2.0          Lord of the rings the two towers    2023-03-24
# 2    3.0  Lord of the rings the return of the kind    2023-03-29
# 3    4.0                                The hobbit    2023-04-02
# 4    5.0                                     Dune     2023-04-02
# 5    6.0                              Little Women    2023-04-02
# 6    7.0                                        IT    2063-04-10
# 7    8.0                                   Misery     2023-04-15
# 8    9.0                                  Catch 22    2023-04-15
# 9   10.0                              Animal Farm     2023-04-20
# 10  11.0                                      1984    2023-04-23
# 11  12.0                              Little Women    2023-04-02
# 12  13.0                              East of Eden    2023-04-30
# ...

# %%
book_data_clean['Book checkout'] = pd.to_datetime(book_data_clean['Book checkout'], errors='coerce', format='%d/%m/%Y')

# %%
import pandas as pd

# Load data
raw_data = pd.read_csv('Data/book.csv', parse_dates=['Book Returned'], date_format='%d/%m/%Y')
book_data = raw_data.copy()
book_data.dropna(inplace=True)

# Clean dates
book_data['Book checkout'] = book_data['Book checkout'].str.replace('"','')
book_data['Book checkout'] = pd.to_datetime(book_data['Book checkout'], errors='coerce', format='%d/%m/%Y')
book_data.dropna(inplace=True)

# Assumptions: checkout should be on or before today and returned should be on or after checkout
book_data = book_data[(book_data['Book checkout'] <= book_data['Book Returned']) & (book_data['Book checkout'] <= pd.Timestamp.today())]

# Clean numbers
book_data['Days allowed to borrow'] = book_data['Days allowed to borrow'].apply(lambda x: 14 if x == '2 weeks' else -1)
book_data = book_data.astype({'Days allowed to borrow': 'int', 
                  'Id': 'int',
                  'Customer ID': 'int'})

# Dedupe 
# Assumption: no one checks out different copies of the same book at the same time
book_data.drop_duplicates(subset=['Books', 'Book checkout', 'Book Returned','Customer ID'], inplace=True)

# Calculate useful values
book_data['Due date'] = book_data['Book checkout'] + pd.to_timedelta(book_data['Days allowed to borrow'], unit='d')
book_data['Days overdue'] = (book_data['Book Returned'] - book_data['Due date']).dt.days
book_data['Days overdue'] = book_data['Days overdue'].apply(lambda x: x if x > 0 else 0)

# %%
from sqlalchemy import create_engine
engine = create_engine("mssql+pyodbc://lib_user:libuser123@localhost/library?trusted_connection=yes&driver=ODBC+Driver+17+for+SQL+Server", echo=True)

# %%
with engine.connect() as connection:
    book_data.to_sql('book',connection, if_exists='replace')
# Out:
# 2025-05-13 10:26:14,805 INFO sqlalchemy.engine.Engine SELECT CAST(SERVERPROPERTY('ProductVersion') AS VARCHAR)
# 2025-05-13 10:26:14,807 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-05-13 10:26:14,809 INFO sqlalchemy.engine.Engine SELECT schema_name()
# 2025-05-13 10:26:14,810 INFO sqlalchemy.engine.Engine [generated in 0.00109s] ()
# 2025-05-13 10:26:14,818 INFO sqlalchemy.engine.Engine SELECT CAST('test max support' AS NVARCHAR(max))
# 2025-05-13 10:26:14,819 INFO sqlalchemy.engine.Engine [generated in 0.00118s] ()
# 2025-05-13 10:26:14,821 INFO sqlalchemy.engine.Engine SELECT 1 FROM fn_listextendedproperty(default, default, default, default, default, default, default)
# 2025-05-13 10:26:14,822 INFO sqlalchemy.engine.Engine [generated in 0.00106s] ()
# 2025-05-13 10:26:14,858 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-13 10:26:14,858 INFO sqlalchemy.engine.Engine SELECT [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME]
# FROM [INFORMATION_SCHEMA].[TABLES]
# ...

# %%
book_data['Loan length'] = (book_data['Book Returned'] - book_data['Book checkout']).dt.days

# %%
display(book_data)
# Out:
#     Id                    Books Book checkout Book Returned  \
# 0    1      Catcher in the Rye     2023-02-20    2023-02-25
# 5    6             Little Women    2023-04-02    2023-05-01
# 8    9                 Catch 22    2023-04-15    2023-04-16
# 9   10             Animal Farm     2023-04-20    2023-04-24
# 10  11                     1984    2023-04-23    2023-04-27
# 12  13             East of Eden    2023-04-30    2023-05-05
# 13  14  America Is in the Heart    2023-05-01    2023-05-07
# 14  15        Wuthering Heights    2023-05-01    2023-05-10
# 15  16               Dark Tales    2023-05-15    2023-06-01
# 17  18           Les Miserables    2023-06-03    2023-06-07
# 18  19                  Dracula    2023-06-10    2023-07-10
# 19  20             Frankenstein    2023-06-01    2023-06-20
#
#     Days allowed to borrow  Customer ID   Due date  Days overdue  Loan length
# 0                       14            1 2023-03-06             0            5
# ...

# %%
raw_cust = pd.read_csv('Data/customer.csv')
customer_data = raw_cust.copy()
customer_data.dropna(inplace=True)
display(customer_data)
# Out:
#    Customer ID     Customer Name
# 0          1.0          Jane Doe
# 1          2.0        John Smith
# 2          3.0        Dan Reeves
# 4          5.0    William Holden
# 5          6.0     Jaztyn Forest
# 6          7.0     Jackie Irving
# 7          8.0  Matthew Stirling
# 8          9.0         Emory Ted

# %%
dropCount = 0
loan_path = 'Data/book.csv'

def csvLoader(filepath):
    raw_data = pd.read_csv(filepath)
    return raw_data

loan_raw = csvLoader(loan_path)
display(loan_raw)
# Out:
#       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye   "20/02/2023"
# 1    2.0          Lord of the rings the two towers  "24/03/2023"
# 2    3.0  Lord of the rings the return of the kind  "29/03/2023"
# 3    4.0                                The hobbit  "02/04/2023"
# 4    5.0                                     Dune   "02/04/2023"
# ..   ...                                       ...           ...
# 109  NaN                                       NaN           NaN
# 110  NaN                                       NaN           NaN
# 111  NaN                                       NaN           NaN
# 112  NaN                                       NaN           NaN
# 113  NaN                                       NaN           NaN
#
#     Book Returned Days allowed to borrow  Customer ID
# 0      25/02/2023                2 weeks          1.0
# 1      21/03/2023                2 weeks          2.0
# ...

# %%
all_loans = pd.DataFrame(data = [[5,'Great Expectations','"11/05/2025"','13/05/2025','2 weeks',1],
                                        [3,'Sprint','04/05/2025','02/05/2025','2 weeks',5]],
                                columns = ['Id','Books','Book checkout','Book Returned','Days allowed to borrow','CustomerId']
                                )
# Out:
#   Cell In[1], line 1
#     all_loans = pd.DataFrame(data: [[5,'Great Expectations','"11/05/2025"','13/05/2025','2 weeks',1],
#                                  ^
# SyntaxError: invalid syntax
